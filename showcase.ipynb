# %%
from network import *
# Out:
# Using TensorFlow backend.

# %%
siamese = build_siamese()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 8, 300)       0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 8, 300)       0
# __________________________________________________________________________________________________
# recurrent_0 (LSTM)              (None, 301)          724808      input_1[0][0]
# __________________________________________________________________________________________________
# recurrent_1 (LSTM)              (None, 301)          724808      input_4[0][0]
# __________________________________________________________________________________________________
# composition (Lambda)            (None, 300)          0           recurrent_0[0][0]
# ...

# %%
h = train_siamese(siamese, spe=50, ne=200)
# Out:
# /home/kokos/Documents/Projects/RI/siamese-paraphrase/siamese-paraphrase-keras/network.py:171: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   h = siamese.fit_generator(read_data(dis, batch_size=bs), steps_per_epoch=spe, nb_epoch=ne)
# /home/kokos/Documents/Projects/RI/siamese-paraphrase/siamese-paraphrase-keras/network.py:171: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., steps_per_epoch=50, epochs=200)`
#   h = siamese.fit_generator(read_data(dis, batch_size=bs), steps_per_epoch=spe, nb_epoch=ne)
# Epoch 1/200
# ...

# %%
histplot(h.history)
